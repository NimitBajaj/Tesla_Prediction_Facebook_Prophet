# %% [markdown]
# <a href="https://colab.research.google.com/github/NimitBajaj/Tesla_Prediction_Facebook_Prophet/blob/main/Tesla_Prediction_Facebook_Prophet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Importing all Necessary Libraries**

# %%
import pandas as pd
import plotly.express as px
from prophet import Prophet

# %%
import plotly.io as pio
pio.renderers.default='colab'

# %% [markdown]
# ## **Importing Dataset and Exploring It**

# %%
df=pd.read_csv("TSLA.csv")

# %%
df
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2021-07-06  681.710022  684.000000  651.400024  659.580017  659.580017
# 1    2021-07-07  664.270020  665.700012  638.320007  644.650024  644.650024
# 2    2021-07-08  628.369995  654.429993  620.460022  652.809998  652.809998
# 3    2021-07-09  653.179993  658.909973  644.690002  656.950012  656.950012
# 4    2021-07-12  662.200012  687.239990  662.159973  685.700012  685.700012
# ..          ...         ...         ...         ...         ...         ...
# 246  2022-06-27  748.099976  756.210022  727.700012  734.760010  734.760010
# 247  2022-06-28  733.450012  749.909973  697.030029  697.989990  697.989990
# 248  2022-06-29  691.500000  693.520020  666.820007  685.469971  685.469971
# 249  2022-06-30  673.530029  688.369995  656.590027  673.419983  673.419983
# 250  2022-07-01  681.000000  690.690002  666.359985  681.789978  681.789978
#
#        Volume
# 0    23284500
# 1    18792000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 251 entries, 0 to 250
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       251 non-null    object
#  1   Open       251 non-null    float64
#  2   High       251 non-null    float64
#  3   Low        251 non-null    float64
#  4   Close      251 non-null    float64
#  5   Adj Close  251 non-null    float64
#  6   Volume     251 non-null    int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 13.9+ KB

# %%
df.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count   251.000000   251.000000   251.000000   251.000000   251.000000
# mean    868.191952   888.561551   845.794981   866.985375   866.985375
# std     160.510480   165.062981   153.717128   159.428178   159.428178
# min     623.849976   647.200012   620.460022   628.159973   628.159973
# 25%     723.480011   740.734985   708.889984   723.309998   723.309998
# 50%     851.450012   869.489990   825.159973   846.349976   846.349976
# 75%    1007.399994  1034.894959   984.920013  1009.825012  1009.825012
# max    1234.410034  1243.489990  1217.000000  1229.910034  1229.910034
#
#              Volume
# count  2.510000e+02
# mean   2.546814e+07
# std    9.007302e+06
# min    9.800600e+06
# 25%    1.901000e+07
# 50%    2.430100e+07
# 75%    3.043895e+07
# max    6.285210e+07

# %% [markdown]
# ## **Data Visualization using plotly express**

# %%
px.area(df, x="Date", y="Close")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.area(df, x="Date", y="Volume")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.bar(df, y="Volume")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.box(df, y="Close")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## **Data Preparation**

# %%
df
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2021-07-06  681.710022  684.000000  651.400024  659.580017  659.580017
# 1    2021-07-07  664.270020  665.700012  638.320007  644.650024  644.650024
# 2    2021-07-08  628.369995  654.429993  620.460022  652.809998  652.809998
# 3    2021-07-09  653.179993  658.909973  644.690002  656.950012  656.950012
# 4    2021-07-12  662.200012  687.239990  662.159973  685.700012  685.700012
# ..          ...         ...         ...         ...         ...         ...
# 246  2022-06-27  748.099976  756.210022  727.700012  734.760010  734.760010
# 247  2022-06-28  733.450012  749.909973  697.030029  697.989990  697.989990
# 248  2022-06-29  691.500000  693.520020  666.820007  685.469971  685.469971
# 249  2022-06-30  673.530029  688.369995  656.590027  673.419983  673.419983
# 250  2022-07-01  681.000000  690.690002  666.359985  681.789978  681.789978
#
#        Volume
# 0    23284500
# 1    18792000
# ...

# %%
column=["Date", "Close"]
ndf=pd.DataFrame(df, columns=column)

# %%
ndf
# Out:
#            Date       Close
# 0    2021-07-06  659.580017
# 1    2021-07-07  644.650024
# 2    2021-07-08  652.809998
# 3    2021-07-09  656.950012
# 4    2021-07-12  685.700012
# ..          ...         ...
# 246  2022-06-27  734.760010
# 247  2022-06-28  697.989990
# 248  2022-06-29  685.469971
# 249  2022-06-30  673.419983
# 250  2022-07-01  681.789978
#
# [251 rows x 2 columns]

# %%
prophet_df=ndf.rename(columns={"Date":"ds", "Close":"y"})

# %%
prophet_df
# Out:
#              ds           y
# 0    2021-07-06  659.580017
# 1    2021-07-07  644.650024
# 2    2021-07-08  652.809998
# 3    2021-07-09  656.950012
# 4    2021-07-12  685.700012
# ..          ...         ...
# 246  2022-06-27  734.760010
# 247  2022-06-28  697.989990
# 248  2022-06-29  685.469971
# 249  2022-06-30  673.419983
# 250  2022-07-01  681.789978
#
# [251 rows x 2 columns]

# %% [markdown]
# ## **Creating Facebook Prophet Model**

# %%
m=Prophet()
m.fit(prophet_df)
# Out:
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkzaio620/t8iark08.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpkzaio620/pu7ptn7x.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=50611', 'data', 'file=/tmp/tmpkzaio620/t8iark08.json', 'init=/tmp/tmpkzaio620/pu7ptn7x.json', 'output', 'file=/tmp/tmpkzaio620/prophet_modelpratqqpv/prophet_model-20250112155718.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 15:57:18 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 15:57:18 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %% [markdown]
# ## **Forecasting**

# %%
future=m.make_future_dataframe(periods=30)
forecast=m.predict(future)

# %%
forecast
# Out:
#             ds       trend  yhat_lower  yhat_upper  trend_lower  trend_upper  \
# 0   2021-07-06  603.574659  480.873821  702.962407   603.574659   603.574659
# 1   2021-07-07  606.689618  495.604394  710.598415   606.689618   606.689618
# 2   2021-07-08  609.804577  480.296463  708.666068   609.804577   609.804577
# 3   2021-07-09  612.919536  488.318942  707.818301   612.919536   612.919536
# 4   2021-07-12  622.264413  508.675182  733.488812   622.264413   622.264413
# ..         ...         ...         ...         ...          ...          ...
# 276 2022-07-27  611.462193  493.113560  714.744946   603.688412   618.449996
# 277 2022-07-28  608.619249  480.377449  709.562733   600.426970   616.232988
# 278 2022-07-29  605.776305  478.406850  695.435834   597.119038   613.850993
# 279 2022-07-30  602.933362  518.716597  742.545818   593.865879   611.496527
# 280 2022-07-31  600.090418  513.396224  735.123064   590.610989   609.247537
#
# ...

# %%
px.line(forecast, x="ds", y="yhat")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
figure=m.plot(forecast, xlabel="ds", ylabel="y")

# %%
figure2=m.plot_components(forecast)

# %% [markdown]
# ## **Downloading the Forecast Data**

# %%
from google.colab import files
forecast.to_csv('forecast.csv')
files.download('forecast.csv')
